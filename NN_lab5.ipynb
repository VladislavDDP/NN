# 1625147.jpg  2217956.jpg  2755875.jpg  3441394.jpg  54540.jpg	 979955.jpg
# 163039.jpg   2224099.jpg  2757327.jpg  3443136.jpg  545561.jpg	 979998.jpg
# 1633289.jpg  2224828.jpg  2760984.jpg  3456440.jpg  56449.jpg	 985164.jpg
# 1635386.jpg  2228322.jpg  276803.jpg   3462250.jpg  568383.jpg	 98617.jpg
# 1636299.jpg  2231356.jpg  2769168.jpg  34632.jpg    568995.jpg	 998719.jpg

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

def view_random_image(target_dir, target_class):
  target_folder = target_dir + target_class
  random_image = random.sample(os.listdir(target_folder), 1)
  img = mpimg.imread(target_folder + '/' + random_image[0])

  plt.title(target_class)

  plt.imshow(img)
  return img

plt.subplot(1, 2, 1)
img = view_random_image(target_dir='pizza_steak/train/', target_class='pizza')

plt.subplot(1, 2, 2)
img = view_random_image(target_dir='pizza_steak/train/', target_class='steak')

# %%
img.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Розв'язок за варіантом

# %%
import zipfile

# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/101_food_classes_10_percent.zip

zip_ref = zipfile.ZipFile("101_food_classes_10_percent.zip", "r")
zip_ref.extractall()
zip_ref.close()
# Out:
# --2022-04-23 12:30:13--  https://storage.googleapis.com/ztm_tf_course/food_vision/101_food_classes_10_percent.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.219.128, 209.85.146.128, 209.85.147.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.219.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1625420029 (1.5G) [application/zip]
# Saving to: ‘101_food_classes_10_percent.zip’
#
# 101_food_classes_10 100%[===================>]   1.51G   202MB/s    in 7.6s
#
# 2022-04-23 12:30:21 (205 MB/s) - ‘101_food_classes_10_percent.zip’ saved [1625420029/1625420029]

# %%
# !ls 101_food_classes_10_percent/train
# Out:
# apple_pie	    eggs_benedict	     onion_rings
# baby_back_ribs	    escargots		     oysters
# baklava		    falafel		     pad_thai
# beef_carpaccio	    filet_mignon	     paella
# beef_tartare	    fish_and_chips	     pancakes
# beet_salad	    foie_gras		     panna_cotta
# beignets	    french_fries	     peking_duck
# bibimbap	    french_onion_soup	     pho
# bread_pudding	    french_toast	     pizza
# breakfast_burrito   fried_calamari	     pork_chop
# bruschetta	    fried_rice		     poutine
# caesar_salad	    frozen_yogurt	     prime_rib
# cannoli		    garlic_bread	     pulled_pork_sandwich
# caprese_salad	    gnocchi		     ramen
# carrot_cake	    greek_salad		     ravioli
# ceviche		    grilled_cheese_sandwich  red_velvet_cake
# cheesecake	    grilled_salmon	     risotto
# cheese_plate	    guacamole		     samosa
# chicken_curry	    gyoza		     sashimi
# chicken_quesadilla  hamburger		     scallops
# chicken_wings	    hot_and_sour_soup	     seaweed_salad
# chocolate_cake	    hot_dog		     shrimp_and_grits
# chocolate_mousse    huevos_rancheros	     spaghetti_bolognese
# churros		    hummus		     spaghetti_carbonara
# clam_chowder	    ice_cream		     spring_rolls
# club_sandwich	    lasagna		     steak
# crab_cakes	    lobster_bisque	     strawberry_shortcake
# creme_brulee	    lobster_roll_sandwich    sushi
# croque_madame	    macaroni_and_cheese      tacos
# cup_cakes	    macarons		     takoyaki
# deviled_eggs	    miso_soup		     tiramisu
# donuts		    mussels		     tuna_tartare
# dumplings	    nachos		     waffles
# edamame		    omelette

# %%
train_dir = "101_food_classes_10_percent/train/"
test_dir = "101_food_classes_10_percent/test/"

# %%
import pathlib
import numpy as np

data_dir = pathlib.Path(train_dir)
all_class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))

indexes = [12, 42, 72]

class_names = np.array([])

for i, name in enumerate(all_class_names):
  if i in indexes:
    print(i, name)
    class_names = np.append(class_names, name)

img = view_random_image(target_dir=train_dir,
                       target_class=random.choice(class_names)) # get a random class name
# Out:
# 12 cannoli
# 42 french_toast
# 72 pancakes

# %%
# !mkdir cannoli_frenchToast_pancakes

# !mkdir cannoli_frenchToast_pancakes/train
# !mkdir cannoli_frenchToast_pancakes/test

# %%
import shutil

sources = [
  'cannoli',
  'french_toast',
  'pancakes'
]

for source in sources:
  source_dir = train_dir + source
  destination_dir = 'cannoli_frenchToast_pancakes/train/' + source
  shutil.copytree(source_dir, destination_dir)

for source in sources:
  source_dir = test_dir + source
  destination_dir = 'cannoli_frenchToast_pancakes/test/' + source
  shutil.copytree(source_dir, destination_dir)

# %%
train_dir = "cannoli_frenchToast_pancakes/train/"
test_dir = "cannoli_frenchToast_pancakes/test/"

# %%
data_dir = pathlib.Path(train_dir)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))

print(class_names)

img = view_random_image(target_dir=train_dir,
                       target_class=random.choice(class_names))
# Out:
# ['cannoli' 'french_toast' 'pancakes']

# %%
# user this command if extra file with checkpoints will be created again
# !rm -rf `find -type d -name .ipynb_checkpoints`

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescale the data and create data generator instances
train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# Load data in from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode='categorical') # changed to categorical

test_data = train_datagen.flow_from_directory(test_dir,
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 225 images belonging to 3 classes.
# Found 750 images belonging to 3 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model_11 = Sequential([
  Conv2D(32, 3, activation='relu', input_shape=(224, 224, 3)),
  MaxPool2D(),
  Dense(128, activation='relu'),
  Conv2D(64, 3, activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(3, activation='softmax')
])

model_11.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_11 = model_11.fit(train_data,
                          epochs=50,
                          steps_per_epoch=len(train_data),
                          validation_data=test_data,
                          validation_steps=len(test_data))
# Out:
# Epoch 1/50
# 8/8 [==============================] - 11s 1s/step - loss: 1.9881 - accuracy: 0.3422 - val_loss: 1.0984 - val_accuracy: 0.3240
# Epoch 2/50
# 8/8 [==============================] - 6s 837ms/step - loss: 1.0956 - accuracy: 0.5333 - val_loss: 1.0981 - val_accuracy: 0.3373
# Epoch 3/50
# 8/8 [==============================] - 6s 838ms/step - loss: 1.0704 - accuracy: 0.5556 - val_loss: 1.1287 - val_accuracy: 0.3333
# Epoch 4/50
# 8/8 [==============================] - 6s 831ms/step - loss: 1.0488 - accuracy: 0.4133 - val_loss: 1.0943 - val_accuracy: 0.3600
# Epoch 5/50
# 8/8 [==============================] - 7s 895ms/step - loss: 0.9817 - accuracy: 0.5689 - val_loss: 1.1095 - val_accuracy: 0.3907
# Epoch 6/50
# 8/8 [==============================] - 6s 828ms/step - loss: 0.9550 - accuracy: 0.5911 - val_loss: 1.1294 - val_accuracy: 0.4507
# Epoch 7/50
# 8/8 [==============================] - 6s 822ms/step - loss: 0.8596 - accuracy: 0.6489 - val_loss: 1.1332 - val_accuracy: 0.4120
# Epoch 8/50
# 8/8 [==============================] - 6s 829ms/step - loss: 0.7235 - accuracy: 0.7556 - val_loss: 1.2369 - val_accuracy: 0.3960
# Epoch 9/50
# 8/8 [==============================] - 7s 874ms/step - loss: 0.5133 - accuracy: 0.8133 - val_loss: 1.3624 - val_accuracy: 0.4293
# Epoch 10/50
# 8/8 [==============================] - 6s 850ms/step - loss: 0.3414 - accuracy: 0.8756 - val_loss: 1.4136 - val_accuracy: 0.4213
# Epoch 11/50
# 8/8 [==============================] - 6s 846ms/step - loss: 0.2374 - accuracy: 0.9422 - val_loss: 1.4348 - val_accuracy: 0.4587
# Epoch 12/50
# 8/8 [==============================] - 6s 849ms/step - loss: 0.1569 - accuracy: 0.9600 - val_loss: 1.5247 - val_accuracy: 0.4560
# Epoch 13/50
# 8/8 [==============================] - 6s 848ms/step - loss: 0.0983 - accuracy: 0.9644 - val_loss: 1.6511 - val_accuracy: 0.4653
# Epoch 14/50
# 8/8 [==============================] - 6s 838ms/step - loss: 0.0530 - accuracy: 0.9867 - val_loss: 2.1087 - val_accuracy: 0.4333
# Epoch 15/50
# 8/8 [==============================] - 6s 854ms/step - loss: 0.0390 - accuracy: 0.9911 - val_loss: 1.7684 - val_accuracy: 0.4520
# Epoch 16/50
# 8/8 [==============================] - 6s 854ms/step - loss: 0.0244 - accuracy: 0.9956 - val_loss: 1.9732 - val_accuracy: 0.4560
# Epoch 17/50
# 8/8 [==============================] - 6s 857ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 2.3212 - val_accuracy: 0.4480
# Epoch 18/50
# 8/8 [==============================] - 6s 852ms/step - loss: 0.0140 - accuracy: 0.9956 - val_loss: 2.4386 - val_accuracy: 0.4427
# Epoch 19/50
# 8/8 [==============================] - 6s 871ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 2.3706 - val_accuracy: 0.4467
# Epoch 20/50
# 8/8 [==============================] - 6s 833ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 2.4940 - val_accuracy: 0.4133
# Epoch 21/50
# 8/8 [==============================] - 6s 830ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.3206 - val_accuracy: 0.4373
# Epoch 22/50
# 8/8 [==============================] - 6s 837ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.3730 - val_accuracy: 0.4360
# Epoch 23/50
# 8/8 [==============================] - 6s 823ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.5567 - val_accuracy: 0.4360
# Epoch 24/50
# 8/8 [==============================] - 6s 825ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.6629 - val_accuracy: 0.4453
# Epoch 25/50
# 8/8 [==============================] - 6s 831ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.7287 - val_accuracy: 0.4493
# Epoch 26/50
# 8/8 [==============================] - 6s 830ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.6907 - val_accuracy: 0.4427
# Epoch 27/50
# 8/8 [==============================] - 6s 798ms/step - loss: 9.3141e-04 - accuracy: 1.0000 - val_loss: 2.6904 - val_accuracy: 0.4413
# Epoch 28/50
# 8/8 [==============================] - 6s 824ms/step - loss: 8.4860e-04 - accuracy: 1.0000 - val_loss: 2.6877 - val_accuracy: 0.4440
# Epoch 29/50
# 8/8 [==============================] - 6s 838ms/step - loss: 7.4992e-04 - accuracy: 1.0000 - val_loss: 2.7080 - val_accuracy: 0.4480
# Epoch 30/50
# 8/8 [==============================] - 6s 817ms/step - loss: 6.4442e-04 - accuracy: 1.0000 - val_loss: 2.7758 - val_accuracy: 0.4453
# Epoch 31/50
# 8/8 [==============================] - 6s 836ms/step - loss: 5.8430e-04 - accuracy: 1.0000 - val_loss: 2.7913 - val_accuracy: 0.4453
# Epoch 32/50
# 8/8 [==============================] - 6s 831ms/step - loss: 5.6945e-04 - accuracy: 1.0000 - val_loss: 2.7251 - val_accuracy: 0.4440
# Epoch 33/50
# 8/8 [==============================] - 6s 834ms/step - loss: 5.4030e-04 - accuracy: 1.0000 - val_loss: 2.7660 - val_accuracy: 0.4493
# Epoch 34/50
# 8/8 [==============================] - 6s 833ms/step - loss: 4.4424e-04 - accuracy: 1.0000 - val_loss: 2.8260 - val_accuracy: 0.4520
# Epoch 35/50
# 8/8 [==============================] - 6s 826ms/step - loss: 4.1870e-04 - accuracy: 1.0000 - val_loss: 2.8480 - val_accuracy: 0.4493
# Epoch 36/50
# 8/8 [==============================] - 6s 810ms/step - loss: 3.8479e-04 - accuracy: 1.0000 - val_loss: 2.8150 - val_accuracy: 0.4493
# Epoch 37/50
# 8/8 [==============================] - 6s 859ms/step - loss: 3.5810e-04 - accuracy: 1.0000 - val_loss: 2.8320 - val_accuracy: 0.4453
# Epoch 38/50
# 8/8 [==============================] - 6s 849ms/step - loss: 3.3181e-04 - accuracy: 1.0000 - val_loss: 2.8793 - val_accuracy: 0.4493
# Epoch 39/50
# 8/8 [==============================] - 7s 875ms/step - loss: 3.0351e-04 - accuracy: 1.0000 - val_loss: 2.9147 - val_accuracy: 0.4507
# Epoch 40/50
# 8/8 [==============================] - 6s 872ms/step - loss: 3.1800e-04 - accuracy: 1.0000 - val_loss: 3.0043 - val_accuracy: 0.4600
# Epoch 41/50
# 8/8 [==============================] - 6s 834ms/step - loss: 2.8614e-04 - accuracy: 1.0000 - val_loss: 2.9315 - val_accuracy: 0.4573
# Epoch 42/50
# 8/8 [==============================] - 6s 827ms/step - loss: 2.6132e-04 - accuracy: 1.0000 - val_loss: 2.8994 - val_accuracy: 0.4587
# Epoch 43/50
# 8/8 [==============================] - 6s 839ms/step - loss: 2.5677e-04 - accuracy: 1.0000 - val_loss: 2.8914 - val_accuracy: 0.4427
# Epoch 44/50
# 8/8 [==============================] - 6s 828ms/step - loss: 2.4637e-04 - accuracy: 1.0000 - val_loss: 2.9403 - val_accuracy: 0.4400
# Epoch 45/50
# 8/8 [==============================] - 6s 831ms/step - loss: 2.1628e-04 - accuracy: 1.0000 - val_loss: 2.9726 - val_accuracy: 0.4453
# Epoch 46/50
# 8/8 [==============================] - 6s 822ms/step - loss: 1.9563e-04 - accuracy: 1.0000 - val_loss: 2.9819 - val_accuracy: 0.4520
# Epoch 47/50
# 8/8 [==============================] - 6s 821ms/step - loss: 1.8605e-04 - accuracy: 1.0000 - val_loss: 2.9970 - val_accuracy: 0.4533
# Epoch 48/50
# 8/8 [==============================] - 6s 806ms/step - loss: 1.7724e-04 - accuracy: 1.0000 - val_loss: 3.0230 - val_accuracy: 0.4507
# Epoch 49/50
# 8/8 [==============================] - 6s 805ms/step - loss: 1.6778e-04 - accuracy: 1.0000 - val_loss: 3.0243 - val_accuracy: 0.4533
# Epoch 50/50
# 8/8 [==============================] - 6s 822ms/step - loss: 2.0367e-04 - accuracy: 1.0000 - val_loss: 3.0745 - val_accuracy: 0.4533

# %%
# Create augmented data generator instance
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=20, # note: this is an int not a float
                                             width_shift_range=0.2,
                                             height_shift_range=0.2,
                                             zoom_range=0.2,
                                             horizontal_flip=True)

train_data_augmented = train_datagen_augmented.flow_from_directory(train_dir,
                                                                  target_size=(224, 224),
                                                                  batch_size=32,
                                                                  class_mode='categorical')
# Out:
# Found 225 images belonging to 3 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model_12 = Sequential([
  Conv2D(32, 3, activation='relu', input_shape=(224, 224, 3)),
  MaxPool2D(),
  Dense(128, activation='relu'),
  Conv2D(64, 3, activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(3, activation='softmax')
])

model_12.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_12 = model_12.fit(train_data_augmented,
                          epochs=50,
                          steps_per_epoch=len(train_data_augmented),
                          validation_data=test_data,
                          validation_steps=len(test_data))
# Out:
# Epoch 1/50
# 8/8 [==============================] - 10s 1s/step - loss: 2.7967 - accuracy: 0.3467 - val_loss: 1.1426 - val_accuracy: 0.3333
# Epoch 2/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1026 - accuracy: 0.3289 - val_loss: 1.0983 - val_accuracy: 0.3747
# Epoch 3/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0983 - accuracy: 0.3733 - val_loss: 1.0982 - val_accuracy: 0.3493
# Epoch 4/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0973 - accuracy: 0.3867 - val_loss: 1.0962 - val_accuracy: 0.3467
# Epoch 5/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0924 - accuracy: 0.4000 - val_loss: 1.0960 - val_accuracy: 0.3373
# Epoch 6/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0720 - accuracy: 0.3911 - val_loss: 1.0642 - val_accuracy: 0.4200
# Epoch 7/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0702 - accuracy: 0.4489 - val_loss: 1.0982 - val_accuracy: 0.3933
# Epoch 8/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0743 - accuracy: 0.4356 - val_loss: 1.0988 - val_accuracy: 0.3827
# Epoch 9/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0794 - accuracy: 0.4844 - val_loss: 1.0904 - val_accuracy: 0.3787
# Epoch 10/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0935 - accuracy: 0.4000 - val_loss: 1.0890 - val_accuracy: 0.3920
# Epoch 11/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0761 - accuracy: 0.4667 - val_loss: 1.0660 - val_accuracy: 0.4573
# Epoch 12/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1013 - accuracy: 0.4444 - val_loss: 1.0854 - val_accuracy: 0.3960
# Epoch 13/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0725 - accuracy: 0.4000 - val_loss: 1.0896 - val_accuracy: 0.3587
# Epoch 14/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0425 - accuracy: 0.4356 - val_loss: 1.1108 - val_accuracy: 0.4013
# Epoch 15/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0516 - accuracy: 0.4356 - val_loss: 1.0771 - val_accuracy: 0.3947
# Epoch 16/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0468 - accuracy: 0.4089 - val_loss: 1.0769 - val_accuracy: 0.4227
# Epoch 17/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0174 - accuracy: 0.4400 - val_loss: 1.0814 - val_accuracy: 0.4173
# Epoch 18/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.9916 - accuracy: 0.4622 - val_loss: 1.1773 - val_accuracy: 0.4240
# Epoch 19/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0288 - accuracy: 0.4667 - val_loss: 1.1154 - val_accuracy: 0.3973
# Epoch 20/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0269 - accuracy: 0.4400 - val_loss: 1.0366 - val_accuracy: 0.4840
# Epoch 21/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.9940 - accuracy: 0.4489 - val_loss: 1.0763 - val_accuracy: 0.4213
# Epoch 22/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0042 - accuracy: 0.4889 - val_loss: 1.1566 - val_accuracy: 0.4560
# Epoch 23/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0950 - accuracy: 0.4356 - val_loss: 1.0895 - val_accuracy: 0.4440
# Epoch 24/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0499 - accuracy: 0.4311 - val_loss: 1.0856 - val_accuracy: 0.4293
# Epoch 25/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0319 - accuracy: 0.4756 - val_loss: 1.1108 - val_accuracy: 0.4013
# Epoch 26/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0472 - accuracy: 0.4444 - val_loss: 1.1718 - val_accuracy: 0.4093
# Epoch 27/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.9691 - accuracy: 0.5467 - val_loss: 1.0443 - val_accuracy: 0.4587
# Epoch 28/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0783 - accuracy: 0.4044 - val_loss: 1.0313 - val_accuracy: 0.4693
# Epoch 29/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0540 - accuracy: 0.4267 - val_loss: 1.1080 - val_accuracy: 0.4400
# Epoch 30/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0269 - accuracy: 0.4622 - val_loss: 1.1685 - val_accuracy: 0.4240
# Epoch 31/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0260 - accuracy: 0.4400 - val_loss: 1.1613 - val_accuracy: 0.4133
# Epoch 32/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0224 - accuracy: 0.4711 - val_loss: 1.1859 - val_accuracy: 0.3947
# Epoch 33/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0501 - accuracy: 0.4533 - val_loss: 1.1488 - val_accuracy: 0.4147
# Epoch 34/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0369 - accuracy: 0.4489 - val_loss: 1.0812 - val_accuracy: 0.4240
# Epoch 35/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0474 - accuracy: 0.4844 - val_loss: 1.0840 - val_accuracy: 0.3893
# Epoch 36/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0763 - accuracy: 0.4089 - val_loss: 1.0839 - val_accuracy: 0.3880
# Epoch 37/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0492 - accuracy: 0.4400 - val_loss: 1.1026 - val_accuracy: 0.4253
# Epoch 38/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.9842 - accuracy: 0.4756 - val_loss: 1.0947 - val_accuracy: 0.4427
# Epoch 39/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0288 - accuracy: 0.4400 - val_loss: 1.0922 - val_accuracy: 0.4093
# Epoch 40/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0336 - accuracy: 0.4578 - val_loss: 1.0800 - val_accuracy: 0.4120
# Epoch 41/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0486 - accuracy: 0.4444 - val_loss: 1.0948 - val_accuracy: 0.4133
# Epoch 42/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.9829 - accuracy: 0.5111 - val_loss: 1.3403 - val_accuracy: 0.3973
# Epoch 43/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.9876 - accuracy: 0.5333 - val_loss: 1.1016 - val_accuracy: 0.4307
# Epoch 44/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.9702 - accuracy: 0.5422 - val_loss: 1.2553 - val_accuracy: 0.4360
# Epoch 45/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0409 - accuracy: 0.5022 - val_loss: 1.2007 - val_accuracy: 0.4200
# Epoch 46/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0532 - accuracy: 0.4489 - val_loss: 1.0784 - val_accuracy: 0.4227
# Epoch 47/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0658 - accuracy: 0.4044 - val_loss: 1.0824 - val_accuracy: 0.4293
# Epoch 48/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0007 - accuracy: 0.4933 - val_loss: 1.1860 - val_accuracy: 0.4280
# Epoch 49/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.9975 - accuracy: 0.5156 - val_loss: 1.1695 - val_accuracy: 0.4347
# Epoch 50/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0156 - accuracy: 0.4622 - val_loss: 1.1136 - val_accuracy: 0.4200

# %%
model_12.save('model.hdf5')

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history_12)

# %%
# Rescale the data and create data generator instances
train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# Load data in from directories and turn it into batches
train_data = train_datagen.flow_from_directory(test_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode='categorical') # changed to categorical

test_data = train_datagen.flow_from_directory(train_dir,
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 750 images belonging to 3 classes.
# Found 225 images belonging to 3 classes.

# %%
# Create augmented data generator instance
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=20, # note: this is an int not a float
                                             width_shift_range=0.2,
                                             height_shift_range=0.2,
                                             zoom_range=0.2,
                                             horizontal_flip=True)

train_data_augmented = train_datagen_augmented.flow_from_directory(test_dir,
                                                                  target_size=(224, 224),
                                                                  batch_size=32,
                                                                  class_mode='categorical')
# Out:
# Found 750 images belonging to 3 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model_12 = Sequential([
  Conv2D(32, 3, activation='relu', input_shape=(224, 224, 3)),
  MaxPool2D(),
  Dense(128, activation='relu'),
  Conv2D(64, 3, activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(3, activation='softmax')
])

model_12.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_12 = model_12.fit(train_data_augmented,
                          epochs=50,
                          steps_per_epoch=len(train_data_augmented),
                          validation_data=test_data,
                          validation_steps=len(test_data))
# Out:
# Epoch 1/50
# 24/24 [==============================] - 16s 641ms/step - loss: 1.4053 - accuracy: 0.3213 - val_loss: 1.0986 - val_accuracy: 0.3422
# Epoch 2/50
# 24/24 [==============================] - 15s 605ms/step - loss: 1.0986 - accuracy: 0.3213 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 3/50
# 24/24 [==============================] - 15s 617ms/step - loss: 1.1008 - accuracy: 0.3133 - val_loss: 1.0982 - val_accuracy: 0.3556
# Epoch 4/50
# 24/24 [==============================] - 15s 627ms/step - loss: 1.0979 - accuracy: 0.3413 - val_loss: 1.0991 - val_accuracy: 0.3378
# Epoch 5/50
# 24/24 [==============================] - 15s 613ms/step - loss: 1.0951 - accuracy: 0.3373 - val_loss: 1.1002 - val_accuracy: 0.3778
# Epoch 6/50
# 24/24 [==============================] - 15s 612ms/step - loss: 1.0974 - accuracy: 0.3560 - val_loss: 1.0978 - val_accuracy: 0.3867
# Epoch 7/50
# 24/24 [==============================] - 15s 617ms/step - loss: 1.0975 - accuracy: 0.3373 - val_loss: 1.0927 - val_accuracy: 0.3156
# Epoch 8/50
# 24/24 [==============================] - 15s 637ms/step - loss: 1.0969 - accuracy: 0.3320 - val_loss: 1.0935 - val_accuracy: 0.3511
# Epoch 9/50
# 24/24 [==============================] - 15s 620ms/step - loss: 1.0785 - accuracy: 0.3640 - val_loss: 1.1033 - val_accuracy: 0.3689
# Epoch 10/50
# 24/24 [==============================] - 15s 623ms/step - loss: 1.0883 - accuracy: 0.3800 - val_loss: 1.0815 - val_accuracy: 0.4444
# Epoch 11/50
# 24/24 [==============================] - 15s 625ms/step - loss: 1.0734 - accuracy: 0.4040 - val_loss: 1.0681 - val_accuracy: 0.4800
# Epoch 12/50
# 24/24 [==============================] - 15s 624ms/step - loss: 1.0602 - accuracy: 0.4120 - val_loss: 1.0924 - val_accuracy: 0.4089
# Epoch 13/50
# 24/24 [==============================] - 15s 620ms/step - loss: 1.0607 - accuracy: 0.4120 - val_loss: 1.0383 - val_accuracy: 0.4000
# Epoch 14/50
# 24/24 [==============================] - 15s 629ms/step - loss: 1.0623 - accuracy: 0.4573 - val_loss: 1.0313 - val_accuracy: 0.4356
# Epoch 15/50
# 24/24 [==============================] - 15s 630ms/step - loss: 1.0381 - accuracy: 0.4587 - val_loss: 1.0253 - val_accuracy: 0.4711
# Epoch 16/50
# 24/24 [==============================] - 15s 637ms/step - loss: 1.0222 - accuracy: 0.4520 - val_loss: 1.0154 - val_accuracy: 0.4267
# Epoch 17/50
# 24/24 [==============================] - 15s 625ms/step - loss: 1.0206 - accuracy: 0.4973 - val_loss: 1.0799 - val_accuracy: 0.4444
# Epoch 18/50
# 24/24 [==============================] - 15s 617ms/step - loss: 1.0401 - accuracy: 0.4613 - val_loss: 1.0278 - val_accuracy: 0.4089
# Epoch 19/50
# 24/24 [==============================] - 15s 622ms/step - loss: 1.0138 - accuracy: 0.4987 - val_loss: 1.0210 - val_accuracy: 0.4756
# Epoch 20/50
# 24/24 [==============================] - 15s 635ms/step - loss: 1.0137 - accuracy: 0.4867 - val_loss: 1.0155 - val_accuracy: 0.4578
# Epoch 21/50
# 24/24 [==============================] - 15s 635ms/step - loss: 0.9948 - accuracy: 0.5040 - val_loss: 1.0071 - val_accuracy: 0.4933
# Epoch 22/50
# 24/24 [==============================] - 15s 623ms/step - loss: 0.9834 - accuracy: 0.5147 - val_loss: 1.0422 - val_accuracy: 0.4533
# Epoch 23/50
# 24/24 [==============================] - 15s 629ms/step - loss: 1.0013 - accuracy: 0.5067 - val_loss: 1.0919 - val_accuracy: 0.3911
# Epoch 24/50
# 24/24 [==============================] - 15s 636ms/step - loss: 1.0069 - accuracy: 0.5080 - val_loss: 1.0310 - val_accuracy: 0.4489
# Epoch 25/50
# 24/24 [==============================] - 15s 628ms/step - loss: 1.0082 - accuracy: 0.5080 - val_loss: 1.0462 - val_accuracy: 0.4756
# Epoch 26/50
# 24/24 [==============================] - 15s 627ms/step - loss: 0.9735 - accuracy: 0.5267 - val_loss: 1.0344 - val_accuracy: 0.4667
# Epoch 27/50
# 24/24 [==============================] - 15s 636ms/step - loss: 0.9715 - accuracy: 0.5293 - val_loss: 1.0657 - val_accuracy: 0.4978
# Epoch 28/50
# 24/24 [==============================] - 15s 628ms/step - loss: 0.9538 - accuracy: 0.5573 - val_loss: 1.0309 - val_accuracy: 0.5111
# Epoch 29/50
# 24/24 [==============================] - 15s 619ms/step - loss: 0.9365 - accuracy: 0.5547 - val_loss: 1.0501 - val_accuracy: 0.5156
# Epoch 30/50
# 24/24 [==============================] - 15s 626ms/step - loss: 0.9939 - accuracy: 0.5293 - val_loss: 1.0155 - val_accuracy: 0.5111
# Epoch 31/50
# 24/24 [==============================] - 15s 626ms/step - loss: 0.9597 - accuracy: 0.5520 - val_loss: 0.9826 - val_accuracy: 0.4978
# Epoch 32/50
# 24/24 [==============================] - 15s 631ms/step - loss: 0.9647 - accuracy: 0.5333 - val_loss: 1.0586 - val_accuracy: 0.5111
# Epoch 33/50
# 24/24 [==============================] - 15s 631ms/step - loss: 0.9295 - accuracy: 0.5627 - val_loss: 1.0981 - val_accuracy: 0.5022
# Epoch 34/50
# 24/24 [==============================] - 15s 623ms/step - loss: 0.9229 - accuracy: 0.5360 - val_loss: 0.9773 - val_accuracy: 0.5467
# Epoch 35/50
# 24/24 [==============================] - 15s 629ms/step - loss: 0.9116 - accuracy: 0.6013 - val_loss: 1.0436 - val_accuracy: 0.5022
# Epoch 36/50
# 24/24 [==============================] - 15s 629ms/step - loss: 0.9031 - accuracy: 0.5760 - val_loss: 1.1267 - val_accuracy: 0.5156
# Epoch 37/50
# 24/24 [==============================] - 15s 625ms/step - loss: 0.9110 - accuracy: 0.5760 - val_loss: 1.0319 - val_accuracy: 0.5467
# Epoch 38/50
# 24/24 [==============================] - 15s 627ms/step - loss: 0.9470 - accuracy: 0.5333 - val_loss: 1.0149 - val_accuracy: 0.4800
# Epoch 39/50
# 24/24 [==============================] - 15s 622ms/step - loss: 0.9031 - accuracy: 0.5813 - val_loss: 1.0056 - val_accuracy: 0.5067
# Epoch 40/50
# 24/24 [==============================] - 15s 626ms/step - loss: 0.9062 - accuracy: 0.5653 - val_loss: 1.0416 - val_accuracy: 0.5200
# Epoch 41/50
# 24/24 [==============================] - 15s 630ms/step - loss: 0.9104 - accuracy: 0.5960 - val_loss: 1.1239 - val_accuracy: 0.5422
# Epoch 42/50
# 24/24 [==============================] - 15s 625ms/step - loss: 0.8955 - accuracy: 0.5840 - val_loss: 1.0625 - val_accuracy: 0.5511
# Epoch 43/50
# 24/24 [==============================] - 15s 628ms/step - loss: 0.9066 - accuracy: 0.5920 - val_loss: 0.9591 - val_accuracy: 0.5200
# Epoch 44/50
# 24/24 [==============================] - 15s 617ms/step - loss: 0.8521 - accuracy: 0.6067 - val_loss: 0.9849 - val_accuracy: 0.5689
# Epoch 45/50
# 24/24 [==============================] - 15s 616ms/step - loss: 0.9221 - accuracy: 0.5827 - val_loss: 1.0152 - val_accuracy: 0.5511
# Epoch 46/50
# 24/24 [==============================] - 15s 613ms/step - loss: 0.8740 - accuracy: 0.6160 - val_loss: 0.9943 - val_accuracy: 0.5644
# Epoch 47/50
# 24/24 [==============================] - 15s 618ms/step - loss: 0.8410 - accuracy: 0.6120 - val_loss: 1.0733 - val_accuracy: 0.5200
# Epoch 48/50
# 24/24 [==============================] - 15s 620ms/step - loss: 0.8842 - accuracy: 0.5853 - val_loss: 1.0030 - val_accuracy: 0.5422
# Epoch 49/50
# 24/24 [==============================] - 15s 625ms/step - loss: 0.8852 - accuracy: 0.5987 - val_loss: 0.9525 - val_accuracy: 0.5600
# Epoch 50/50
# 24/24 [==============================] - 15s 626ms/step - loss: 0.8458 - accuracy: 0.6160 - val_loss: 1.0076 - val_accuracy: 0.5733

# %%
plot_loss_curves(history_12)

# %% [markdown]
# # Висновок
# На лабораторній роботі було застосовано convolutional нейронну мережу для роспізнавання страв на картінках. За результатами можна встановити той факт, що мережа погано навчилася через маленьку кількість даних на тренувальному наборі. Оскільки було взято лише 10% від всієї навчальної виборки.
